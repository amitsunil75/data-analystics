# %%
import pandas as pd
import numpy as np

# Define the columns for the dataset
columns = [
    "Transaction_ID", "User_ID", "Transaction_Amount", "Transaction_Date", 
    "Transaction_Time", "Merchant_Name", "Merchant_Location", "Payment_Method", 
    "Transaction_Status", "Fraud_Flag", "User_Account_Balance", "User_Device_Type", 
    "User_Transaction_History_Count", "User_Age", "User_Gender", "User_Country", 
    "Transaction_Type", "Merchant_Category", "User_Account_Status"
]

# Generate synthetic data
np.random.seed(42)
data = {
    "Transaction_ID": [f"TID{1000+i}" for i in range(2000)],
    "User_ID": [f"UID{np.random.randint(1000, 2000)}" for _ in range(2000)],
    "Transaction_Amount": np.round(np.random.uniform(10, 5000, 2000), 2),
    "Transaction_Date": pd.date_range(start="2024-01-01", periods=2000, freq="H").date,
    "Transaction_Time": pd.date_range(start="2024-01-01", periods=2000, freq="H").time,
    "Merchant_Name": [f"Merchant_{np.random.randint(1, 100)}" for _ in range(2000)],
    "Merchant_Location": [f"Location_{np.random.randint(1, 50)}" for _ in range(2000)],
    "Payment_Method": np.random.choice(["UPI", "Credit Card", "Debit Card", "Net Banking"], 2000),
    "Transaction_Status": np.random.choice(["Success", "Failed", "Pending"], 2000),
    "Fraud_Flag": np.random.choice([0, 1], 2000, p=[0.95, 0.05]),  # 5% fraud rate
    "User_Account_Balance": np.round(np.random.uniform(1000, 100000, 2000), 2),
    "User_Device_Type": np.random.choice(["Android", "iOS"], 2000),
    "User_Transaction_History_Count": np.random.randint(1, 500, 2000),
    "User_Age": np.random.randint(18, 70, 2000),
    "User_Gender": np.random.choice(["Male", "Female", "Other"], 2000),
    "User_Country": np.random.choice(["India", "USA", "UK", "Germany", "Australia", "Canada"], 2000),
    "Transaction_Type": np.random.choice(["Purchase", "Transfer", "Withdrawal", "Deposit"], 2000),
    "Merchant_Category": np.random.choice(["Grocery", "Electronics", "Fashion", "Healthcare", "Travel"], 2000),
    "User_Account_Status": np.random.choice(["Active", "Inactive", "Suspended"], 2000)
}

# %%
df = pd.DataFrame(data)

# Save to CSV
file_path = "gpay_fraud_transaction_analysis_extended.csv"
df.to_csv(file_path, index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statistics
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# %%
file_path = 'gpay_fraud_transaction_analysis_extended.csv'
df = pd.read_csv(file_path)
df
# Out:
#      Transaction_ID  User_ID  Transaction_Amount Transaction_Date  \
# 0           TID1000  UID1102             4311.59       2024-01-01
# 1           TID1001  UID1435             4224.30       2024-01-01
# 2           TID1002  UID1860             1602.31       2024-01-01
# 3           TID1003  UID1270             4146.29       2024-01-01
# 4           TID1004  UID1106              194.67       2024-01-01
# ...             ...      ...                 ...              ...
# 1995        TID2995  UID1826             2169.51       2024-03-24
# 1996        TID2996  UID1726             3430.36       2024-03-24
# 1997        TID2997  UID1476             1668.96       2024-03-24
# 1998        TID2998  UID1593              292.36       2024-03-24
# 1999        TID2999  UID1222             1875.87       2024-03-24
#
#      Transaction_Time Merchant_Name Merchant_Location Payment_Method  \
# 0            00:00:00   Merchant_68        Location_1    Net Banking
# 1            01:00:00   Merchant_33       Location_26            UPI
# 2            02:00:00   Merchant_13       Location_23     Debit Card
# 3            03:00:00   Merchant_84       Location_26    Credit Card
# 4            04:00:00   Merchant_54       Location_45    Credit Card
# ...               ...           ...               ...            ...
# 1995         03:00:00   Merchant_36       Location_20    Credit Card
# 1996         04:00:00   Merchant_18        Location_8    Net Banking
# 1997         05:00:00   Merchant_90       Location_46    Credit Card
# 1998         06:00:00   Merchant_53       Location_31     Debit Card
# 1999         07:00:00   Merchant_71       Location_29    Net Banking
#
#      Transaction_Status  Fraud_Flag  User_Account_Balance User_Device_Type  \
# 0                Failed           0              83865.19          Android
# 1                Failed           0               8811.28          Android
# 2               Pending           0              10044.03              iOS
# 3               Pending           1              43313.42              iOS
# 4               Pending           1              14344.99              iOS
# ...                 ...         ...                   ...              ...
# 1995            Pending           0              70734.22              iOS
# 1996            Pending           0              89149.48          Android
# 1997             Failed           0              91673.17          Android
# 1998             Failed           0              28493.85              iOS
# 1999            Success           0              19601.11          Android
#
#       User_Transaction_History_Count  User_Age User_Gender User_Country  \
# 0                                409        32       Other    Australia
# 1                                102        68       Other    Australia
# 2                                 44        23       Other           UK
# 3                                 15        44        Male      Germany
# 4                                236        22      Female      Germany
# ...                              ...       ...         ...          ...
# 1995                              12        33      Female      Germany
# 1996                             160        56        Male          USA
# 1997                             417        35      Female       Canada
# 1998                             458        56        Male          USA
# 1999                             196        18       Other    Australia
#
#      Transaction_Type Merchant_Category User_Account_Status
# 0             Deposit           Grocery            Inactive
# 1             Deposit           Fashion           Suspended
# 2             Deposit            Travel              Active
# 3             Deposit           Fashion            Inactive
# 4            Transfer           Fashion           Suspended
# ...               ...               ...                 ...
# 1995       Withdrawal        Healthcare           Suspended
# 1996         Purchase            Travel           Suspended
# 1997         Transfer        Healthcare              Active
# 1998       Withdrawal       Electronics            Inactive
# 1999          Deposit            Travel              Active
#
# [2000 rows x 19 columns]

# %%
mean_transaction_amount = df['Transaction_Amount'].mean()
median_transaction_amount = df['Transaction_Amount'].median()
mode_transaction_amount = df['Transaction_Amount'].mode()[0]
std_dev_transaction_amount = df['Transaction_Amount'].std()

# For User Account Balance
mean_user_balance = df['User_Account_Balance'].mean()
median_user_balance = df['User_Account_Balance'].median()
mode_user_balance = df['User_Account_Balance'].mode()[0]
std_dev_user_balance = df['User_Account_Balance'].std()

# For User Age
mean_user_age = df['User_Age'].mean()
median_user_age = df['User_Age'].median()
mode_user_age = df['User_Age'].mode()[0]
std_dev_user_age = df['User_Age'].std()

# %%
print("Transaction Amount - Mean: ", mean_transaction_amount)
print("Transaction Amount - Median: ", median_transaction_amount)
print("Transaction Amount - Mode: ", mode_transaction_amount)
print("Standard deviation Transaction ", std_dev_transaction_amount)

print("\nUser Account Balance - Mean: ", mean_user_balance)
print("User Account Balance - Median: ", median_user_balance)
print("User Account Balance - Mode: ", mode_user_balance)
print("Standard deviation Balance ", std_dev_user_balance)


print("\nUser Age - Mean: ", mean_user_age)
print("User Age - Median: ", median_user_age)
print("User Age - Mode: ", mode_user_age)
print("Standard deviation User Age",std_dev_user_age)
# Out:
# Transaction Amount - Mean:  2518.7631800000004
# Transaction Amount - Median:  2540.315
# Transaction Amount - Mode:  981.17
# Standard deviation Transaction  1449.727265060679
#
# User Account Balance - Mean:  50574.43492
# User Account Balance - Median:  50124.350000000006
# User Account Balance - Mode:  1018.33
# Standard deviation Balance  28440.82299497866
#
# User Age - Mean:  43.262
# User Age - Median:  43.0
# User Age - Mode:  24
# Standard deviation User Age 15.110576453609596

# %%
sns.set(style="whitegrid")

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Transaction_Amount'], kde=True, color='blue')
plt.title('Distribution of Transaction Amount')
plt.xlabel('Transaction Amount')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['User_Account_Balance'], kde=True, color='green')
plt.title('Distribution of User Account Balance')
plt.xlabel('User Account Balance')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# User Age
plt.figure(figsize=(10, 6))
sns.histplot(df['User_Age'], kde=True, color='red')
plt.title('Distribution of User Age')
plt.xlabel('User Age')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Scatter plot for Transaction Amount vs. User Account Balance
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Transaction_Amount', y='User_Account_Balance', data=df, hue='Fraud_Flag', palette='coolwarm')
plt.title('Transaction Amount vs. User Account Balance')
plt.xlabel('Transaction Amount')
plt.ylabel('User Account Balance')
plt.show()

# %%
# Scatter plot for User Age vs. Transaction Amount
plt.figure(figsize=(10, 6))
sns.scatterplot(x='User_Age', y='Transaction_Amount', data=df, hue='Fraud_Flag', palette='viridis')
plt.title('User Age vs. Transaction Amount')
plt.xlabel('User Age')
plt.ylabel('Transaction Amount')
plt.show()

# %%
df
# Out:
#      Transaction_ID  User_ID  Transaction_Amount Transaction_Date  \
# 0           TID1000  UID1102             4311.59       2024-01-01
# 1           TID1001  UID1435             4224.30       2024-01-01
# 2           TID1002  UID1860             1602.31       2024-01-01
# 3           TID1003  UID1270             4146.29       2024-01-01
# 4           TID1004  UID1106              194.67       2024-01-01
# ...             ...      ...                 ...              ...
# 1995        TID2995  UID1826             2169.51       2024-03-24
# 1996        TID2996  UID1726             3430.36       2024-03-24
# 1997        TID2997  UID1476             1668.96       2024-03-24
# 1998        TID2998  UID1593              292.36       2024-03-24
# 1999        TID2999  UID1222             1875.87       2024-03-24
#
#      Transaction_Time Merchant_Name Merchant_Location Payment_Method  \
# 0            00:00:00   Merchant_68        Location_1    Net Banking
# 1            01:00:00   Merchant_33       Location_26            UPI
# 2            02:00:00   Merchant_13       Location_23     Debit Card
# 3            03:00:00   Merchant_84       Location_26    Credit Card
# 4            04:00:00   Merchant_54       Location_45    Credit Card
# ...               ...           ...               ...            ...
# 1995         03:00:00   Merchant_36       Location_20    Credit Card
# 1996         04:00:00   Merchant_18        Location_8    Net Banking
# 1997         05:00:00   Merchant_90       Location_46    Credit Card
# 1998         06:00:00   Merchant_53       Location_31     Debit Card
# 1999         07:00:00   Merchant_71       Location_29    Net Banking
#
#      Transaction_Status  Fraud_Flag  User_Account_Balance User_Device_Type  \
# 0                Failed           0              83865.19          Android
# 1                Failed           0               8811.28          Android
# 2               Pending           0              10044.03              iOS
# 3               Pending           1              43313.42              iOS
# 4               Pending           1              14344.99              iOS
# ...                 ...         ...                   ...              ...
# 1995            Pending           0              70734.22              iOS
# 1996            Pending           0              89149.48          Android
# 1997             Failed           0              91673.17          Android
# 1998             Failed           0              28493.85              iOS
# 1999            Success           0              19601.11          Android
#
#       User_Transaction_History_Count  User_Age User_Gender User_Country  \
# 0                                409        32       Other    Australia
# 1                                102        68       Other    Australia
# 2                                 44        23       Other           UK
# 3                                 15        44        Male      Germany
# 4                                236        22      Female      Germany
# ...                              ...       ...         ...          ...
# 1995                              12        33      Female      Germany
# 1996                             160        56        Male          USA
# 1997                             417        35      Female       Canada
# 1998                             458        56        Male          USA
# 1999                             196        18       Other    Australia
#
#      Transaction_Type Merchant_Category User_Account_Status
# 0             Deposit           Grocery            Inactive
# 1             Deposit           Fashion           Suspended
# 2             Deposit            Travel              Active
# 3             Deposit           Fashion            Inactive
# 4            Transfer           Fashion           Suspended
# ...               ...               ...                 ...
# 1995       Withdrawal        Healthcare           Suspended
# 1996         Purchase            Travel           Suspended
# 1997         Transfer        Healthcare              Active
# 1998       Withdrawal       Electronics            Inactive
# 1999          Deposit            Travel              Active
#
# [2000 rows x 19 columns]

# %%
 df['Transaction_Amount'].fillna(df['Transaction_Amount'].mean(), inplace=True)

# %%
columns_to_drop = [
    'Transaction_ID',
    'User_ID',
    'Transaction_Date',
    'Transaction_Time',
    'Merchant_Name',
    'Merchant_Location',
    'User_Gender',
    'User_Country',
    'Transaction_Type',
    'User_Device_Type'
]

# Drop the specified columns
df = df.drop(columns=columns_to_drop)

# %%
df
# Out:
#       Transaction_Amount Payment_Method Transaction_Status  Fraud_Flag  \
# 0                4311.59    Net Banking             Failed           0
# 1                4224.30            UPI             Failed           0
# 2                1602.31     Debit Card            Pending           0
# 3                4146.29    Credit Card            Pending           1
# 4                 194.67    Credit Card            Pending           1
# ...                  ...            ...                ...         ...
# 1995             2169.51    Credit Card            Pending           0
# 1996             3430.36    Net Banking            Pending           0
# 1997             1668.96    Credit Card             Failed           0
# 1998              292.36     Debit Card             Failed           0
# 1999             1875.87    Net Banking            Success           0
#
#       User_Account_Balance  User_Transaction_History_Count  User_Age  \
# 0                 83865.19                             409        32
# 1                  8811.28                             102        68
# 2                 10044.03                              44        23
# 3                 43313.42                              15        44
# 4                 14344.99                             236        22
# ...                    ...                             ...       ...
# 1995              70734.22                              12        33
# 1996              89149.48                             160        56
# 1997              91673.17                             417        35
# 1998              28493.85                             458        56
# 1999              19601.11                             196        18
#
#      Merchant_Category User_Account_Status
# 0              Grocery            Inactive
# 1              Fashion           Suspended
# 2               Travel              Active
# 3              Fashion            Inactive
# 4              Fashion           Suspended
# ...                ...                 ...
# 1995        Healthcare           Suspended
# 1996            Travel           Suspended
# 1997        Healthcare              Active
# 1998       Electronics            Inactive
# 1999            Travel              Active
#
# [2000 rows x 9 columns]

# %%
payment_method_dummies = pd.get_dummies(df['Payment_Method'], prefix='Payment_Method').astype(int)
df = pd.concat([df, payment_method_dummies], axis=1)
df.drop('Payment_Method', axis=1, inplace=True)

# %%
df
# Out:
#       Transaction_Amount Transaction_Status  Fraud_Flag  User_Account_Balance  \
# 0                4311.59             Failed           0              83865.19
# 1                4224.30             Failed           0               8811.28
# 2                1602.31            Pending           0              10044.03
# 3                4146.29            Pending           1              43313.42
# 4                 194.67            Pending           1              14344.99
# ...                  ...                ...         ...                   ...
# 1995             2169.51            Pending           0              70734.22
# 1996             3430.36            Pending           0              89149.48
# 1997             1668.96             Failed           0              91673.17
# 1998              292.36             Failed           0              28493.85
# 1999             1875.87            Success           0              19601.11
#
#       User_Transaction_History_Count  User_Age Merchant_Category  \
# 0                                409        32           Grocery
# 1                                102        68           Fashion
# 2                                 44        23            Travel
# 3                                 15        44           Fashion
# 4                                236        22           Fashion
# ...                              ...       ...               ...
# 1995                              12        33        Healthcare
# 1996                             160        56            Travel
# 1997                             417        35        Healthcare
# 1998                             458        56       Electronics
# 1999                             196        18            Travel
#
#      User_Account_Status  Payment_Method_Credit Card  \
# 0               Inactive                           0
# 1              Suspended                           0
# 2                 Active                           0
# 3               Inactive                           1
# 4              Suspended                           1
# ...                  ...                         ...
# 1995           Suspended                           1
# 1996           Suspended                           0
# 1997              Active                           1
# 1998            Inactive                           0
# 1999              Active                           0
#
#       Payment_Method_Debit Card  Payment_Method_Net Banking  \
# 0                             0                           1
# 1                             0                           0
# 2                             1                           0
# 3                             0                           0
# 4                             0                           0
# ...                         ...                         ...
# 1995                          0                           0
# 1996                          0                           1
# 1997                          0                           0
# 1998                          1                           0
# 1999                          0                           1
#
#       Payment_Method_UPI
# 0                      0
# 1                      1
# 2                      0
# 3                      0
# 4                      0
# ...                  ...
# 1995                   0
# 1996                   0
# 1997                   0
# 1998                   0
# 1999                   0
#
# [2000 rows x 12 columns]

# %%
transcation_status = pd.get_dummies(df['Transaction_Status'], prefix='Transaction_Status').astype(int)
df = pd.concat([df, transcation_status], axis=1)
df.drop('Transaction_Status', axis=1, inplace=True)

# %%
df
# Out:
#       Transaction_Amount  Fraud_Flag  User_Account_Balance  \
# 0                4311.59           0              83865.19
# 1                4224.30           0               8811.28
# 2                1602.31           0              10044.03
# 3                4146.29           1              43313.42
# 4                 194.67           1              14344.99
# ...                  ...         ...                   ...
# 1995             2169.51           0              70734.22
# 1996             3430.36           0              89149.48
# 1997             1668.96           0              91673.17
# 1998              292.36           0              28493.85
# 1999             1875.87           0              19601.11
#
#       User_Transaction_History_Count  User_Age Merchant_Category  \
# 0                                409        32           Grocery
# 1                                102        68           Fashion
# 2                                 44        23            Travel
# 3                                 15        44           Fashion
# 4                                236        22           Fashion
# ...                              ...       ...               ...
# 1995                              12        33        Healthcare
# 1996                             160        56            Travel
# 1997                             417        35        Healthcare
# 1998                             458        56       Electronics
# 1999                             196        18            Travel
#
#      User_Account_Status  Payment_Method_Credit Card  \
# 0               Inactive                           0
# 1              Suspended                           0
# 2                 Active                           0
# 3               Inactive                           1
# 4              Suspended                           1
# ...                  ...                         ...
# 1995           Suspended                           1
# 1996           Suspended                           0
# 1997              Active                           1
# 1998            Inactive                           0
# 1999              Active                           0
#
#       Payment_Method_Debit Card  Payment_Method_Net Banking  \
# 0                             0                           1
# 1                             0                           0
# 2                             1                           0
# 3                             0                           0
# 4                             0                           0
# ...                         ...                         ...
# 1995                          0                           0
# 1996                          0                           1
# 1997                          0                           0
# 1998                          1                           0
# 1999                          0                           1
#
#       Payment_Method_UPI  Transaction_Status_Failed  \
# 0                      0                          1
# 1                      1                          1
# 2                      0                          0
# 3                      0                          0
# 4                      0                          0
# ...                  ...                        ...
# 1995                   0                          0
# 1996                   0                          0
# 1997                   0                          1
# 1998                   0                          1
# 1999                   0                          0
#
#       Transaction_Status_Pending  Transaction_Status_Success
# 0                              0                           0
# 1                              0                           0
# 2                              1                           0
# 3                              1                           0
# 4                              1                           0
# ...                          ...                         ...
# 1995                           1                           0
# 1996                           1                           0
# 1997                           0                           0
# 1998                           0                           0
# 1999                           0                           1
#
# [2000 rows x 14 columns]

# %%
user_account_status = pd.get_dummies(df['User_Account_Status'], prefix='User_Account_Status').astype(int)
df = pd.concat([df, user_account_status], axis=1)
df.drop('User_Account_Status', axis=1, inplace=True)

# %%
df
# Out:
#       Transaction_Amount  Fraud_Flag  User_Account_Balance  \
# 0                4311.59           0              83865.19
# 1                4224.30           0               8811.28
# 2                1602.31           0              10044.03
# 3                4146.29           1              43313.42
# 4                 194.67           1              14344.99
# ...                  ...         ...                   ...
# 1995             2169.51           0              70734.22
# 1996             3430.36           0              89149.48
# 1997             1668.96           0              91673.17
# 1998              292.36           0              28493.85
# 1999             1875.87           0              19601.11
#
#       User_Transaction_History_Count  User_Age Merchant_Category  \
# 0                                409        32           Grocery
# 1                                102        68           Fashion
# 2                                 44        23            Travel
# 3                                 15        44           Fashion
# 4                                236        22           Fashion
# ...                              ...       ...               ...
# 1995                              12        33        Healthcare
# 1996                             160        56            Travel
# 1997                             417        35        Healthcare
# 1998                             458        56       Electronics
# 1999                             196        18            Travel
#
#       Payment_Method_Credit Card  Payment_Method_Debit Card  \
# 0                              0                          0
# 1                              0                          0
# 2                              0                          1
# 3                              1                          0
# 4                              1                          0
# ...                          ...                        ...
# 1995                           1                          0
# 1996                           0                          0
# 1997                           1                          0
# 1998                           0                          1
# 1999                           0                          0
#
#       Payment_Method_Net Banking  Payment_Method_UPI  \
# 0                              1                   0
# 1                              0                   1
# 2                              0                   0
# 3                              0                   0
# 4                              0                   0
# ...                          ...                 ...
# 1995                           0                   0
# 1996                           1                   0
# 1997                           0                   0
# 1998                           0                   0
# 1999                           1                   0
#
#       Transaction_Status_Failed  Transaction_Status_Pending  \
# 0                             1                           0
# 1                             1                           0
# 2                             0                           1
# 3                             0                           1
# 4                             0                           1
# ...                         ...                         ...
# 1995                          0                           1
# 1996                          0                           1
# 1997                          1                           0
# 1998                          1                           0
# 1999                          0                           0
#
#       Transaction_Status_Success  User_Account_Status_Active  \
# 0                              0                           0
# 1                              0                           0
# 2                              0                           1
# 3                              0                           0
# 4                              0                           0
# ...                          ...                         ...
# 1995                           0                           0
# 1996                           0                           0
# 1997                           0                           1
# 1998                           0                           0
# 1999                           1                           1
#
#       User_Account_Status_Inactive  User_Account_Status_Suspended
# 0                                1                              0
# 1                                0                              1
# 2                                0                              0
# 3                                1                              0
# 4                                0                              1
# ...                            ...                            ...
# 1995                             0                              1
# 1996                             0                              1
# 1997                             0                              0
# 1998                             1                              0
# 1999                             0                              0
#
# [2000 rows x 16 columns]

# %%
merchant_category = pd.get_dummies(df['Merchant_Category'], prefix='Merchant_Category').astype(int)
df = pd.concat([df,merchant_category], axis=1)
df.drop('Merchant_Category', axis=1, inplace=True)

# %%
df
# Out:
#       Transaction_Amount  Fraud_Flag  User_Account_Balance  \
# 0                4311.59           0              83865.19
# 1                4224.30           0               8811.28
# 2                1602.31           0              10044.03
# 3                4146.29           1              43313.42
# 4                 194.67           1              14344.99
# ...                  ...         ...                   ...
# 1995             2169.51           0              70734.22
# 1996             3430.36           0              89149.48
# 1997             1668.96           0              91673.17
# 1998              292.36           0              28493.85
# 1999             1875.87           0              19601.11
#
#       User_Transaction_History_Count  User_Age  Payment_Method_Credit Card  \
# 0                                409        32                           0
# 1                                102        68                           0
# 2                                 44        23                           0
# 3                                 15        44                           1
# 4                                236        22                           1
# ...                              ...       ...                         ...
# 1995                              12        33                           1
# 1996                             160        56                           0
# 1997                             417        35                           1
# 1998                             458        56                           0
# 1999                             196        18                           0
#
#       Payment_Method_Debit Card  Payment_Method_Net Banking  \
# 0                             0                           1
# 1                             0                           0
# 2                             1                           0
# 3                             0                           0
# 4                             0                           0
# ...                         ...                         ...
# 1995                          0                           0
# 1996                          0                           1
# 1997                          0                           0
# 1998                          1                           0
# 1999                          0                           1
#
#       Payment_Method_UPI  Transaction_Status_Failed  \
# 0                      0                          1
# 1                      1                          1
# 2                      0                          0
# 3                      0                          0
# 4                      0                          0
# ...                  ...                        ...
# 1995                   0                          0
# 1996                   0                          0
# 1997                   0                          1
# 1998                   0                          1
# 1999                   0                          0
#
#       Transaction_Status_Pending  Transaction_Status_Success  \
# 0                              0                           0
# 1                              0                           0
# 2                              1                           0
# 3                              1                           0
# 4                              1                           0
# ...                          ...                         ...
# 1995                           1                           0
# 1996                           1                           0
# 1997                           0                           0
# 1998                           0                           0
# 1999                           0                           1
#
#       User_Account_Status_Active  User_Account_Status_Inactive  \
# 0                              0                             1
# 1                              0                             0
# 2                              1                             0
# 3                              0                             1
# 4                              0                             0
# ...                          ...                           ...
# 1995                           0                             0
# 1996                           0                             0
# 1997                           1                             0
# 1998                           0                             1
# 1999                           1                             0
#
#       User_Account_Status_Suspended  Merchant_Category_Electronics  \
# 0                                 0                              0
# 1                                 1                              0
# 2                                 0                              0
# 3                                 0                              0
# 4                                 1                              0
# ...                             ...                            ...
# 1995                              1                              0
# 1996                              1                              0
# 1997                              0                              0
# 1998                              0                              1
# 1999                              0                              0
#
#       Merchant_Category_Fashion  Merchant_Category_Grocery  \
# 0                             0                          1
# 1                             1                          0
# 2                             0                          0
# 3                             1                          0
# 4                             1                          0
# ...                         ...                        ...
# 1995                          0                          0
# 1996                          0                          0
# 1997                          0                          0
# 1998                          0                          0
# 1999                          0                          0
#
#       Merchant_Category_Healthcare  Merchant_Category_Travel
# 0                                0                         0
# 1                                0                         0
# 2                                0                         1
# 3                                0                         0
# 4                                0                         0
# ...                            ...                       ...
# 1995                             1                         0
# 1996                             0                         1
# 1997                             1                         0
# 1998                             0                         0
# 1999                             0                         1
#
# [2000 rows x 20 columns]

# %%
df['Transaction_Amount'].fillna(df['Transaction_Amount'].mean(), inplace=True)

# %%
scaler = MinMaxScaler()

# %%
df['Transaction_Amount'] = scaler.fit_transform(df['Transaction_Amount'].values.reshape(-1, 1))

# %%
df
# Out:
#       Transaction_Amount  Fraud_Flag  User_Account_Balance  \
# 0               0.862547           0              83865.19
# 1               0.845043           0               8811.28
# 2               0.319279           0              10044.03
# 3               0.829401           1              43313.42
# 4               0.037018           1              14344.99
# ...                  ...         ...                   ...
# 1995            0.433015           0              70734.22
# 1996            0.685842           0              89149.48
# 1997            0.332644           0              91673.17
# 1998            0.056607           0              28493.85
# 1999            0.374134           0              19601.11
#
#       User_Transaction_History_Count  User_Age  Payment_Method_Credit Card  \
# 0                                409        32                           0
# 1                                102        68                           0
# 2                                 44        23                           0
# 3                                 15        44                           1
# 4                                236        22                           1
# ...                              ...       ...                         ...
# 1995                              12        33                           1
# 1996                             160        56                           0
# 1997                             417        35                           1
# 1998                             458        56                           0
# 1999                             196        18                           0
#
#       Payment_Method_Debit Card  Payment_Method_Net Banking  \
# 0                             0                           1
# 1                             0                           0
# 2                             1                           0
# 3                             0                           0
# 4                             0                           0
# ...                         ...                         ...
# 1995                          0                           0
# 1996                          0                           1
# 1997                          0                           0
# 1998                          1                           0
# 1999                          0                           1
#
#       Payment_Method_UPI  Transaction_Status_Failed  \
# 0                      0                          1
# 1                      1                          1
# 2                      0                          0
# 3                      0                          0
# 4                      0                          0
# ...                  ...                        ...
# 1995                   0                          0
# 1996                   0                          0
# 1997                   0                          1
# 1998                   0                          1
# 1999                   0                          0
#
#       Transaction_Status_Pending  Transaction_Status_Success  \
# 0                              0                           0
# 1                              0                           0
# 2                              1                           0
# 3                              1                           0
# 4                              1                           0
# ...                          ...                         ...
# 1995                           1                           0
# 1996                           1                           0
# 1997                           0                           0
# 1998                           0                           0
# 1999                           0                           1
#
#       User_Account_Status_Active  User_Account_Status_Inactive  \
# 0                              0                             1
# 1                              0                             0
# 2                              1                             0
# 3                              0                             1
# 4                              0                             0
# ...                          ...                           ...
# 1995                           0                             0
# 1996                           0                             0
# 1997                           1                             0
# 1998                           0                             1
# 1999                           1                             0
#
#       User_Account_Status_Suspended  Merchant_Category_Electronics  \
# 0                                 0                              0
# 1                                 1                              0
# 2                                 0                              0
# 3                                 0                              0
# 4                                 1                              0
# ...                             ...                            ...
# 1995                              1                              0
# 1996                              1                              0
# 1997                              0                              0
# 1998                              0                              1
# 1999                              0                              0
#
#       Merchant_Category_Fashion  Merchant_Category_Grocery  \
# 0                             0                          1
# 1                             1                          0
# 2                             0                          0
# 3                             1                          0
# 4                             1                          0
# ...                         ...                        ...
# 1995                          0                          0
# 1996                          0                          0
# 1997                          0                          0
# 1998                          0                          0
# 1999                          0                          0
#
#       Merchant_Category_Healthcare  Merchant_Category_Travel
# 0                                0                         0
# 1                                0                         0
# 2                                0                         1
# 3                                0                         0
# 4                                0                         0
# ...                            ...                       ...
# 1995                             1                         0
# 1996                             0                         1
# 1997                             1                         0
# 1998                             0                         0
# 1999                             0                         1
#
# [2000 rows x 20 columns]

# %%
df['User_Account_Balance'].fillna(df['User_Account_Balance'].mean(), inplace=True)

# %%
df['User_Account_Balance'] = scaler.fit_transform(df['User_Account_Balance'].values.reshape(-1, 1))

# %%
df
# Out:
#       Transaction_Amount  Fraud_Flag  User_Account_Balance  \
# 0               0.862547           0              0.837297
# 1               0.845043           0              0.078760
# 2               0.319279           0              0.091219
# 3               0.829401           1              0.427458
# 4               0.037018           1              0.134687
# ...                  ...         ...                   ...
# 1995            0.433015           0              0.704588
# 1996            0.685842           0              0.890703
# 1997            0.332644           0              0.916209
# 1998            0.056607           0              0.277683
# 1999            0.374134           0              0.187808
#
#       User_Transaction_History_Count  User_Age  Payment_Method_Credit Card  \
# 0                                409        32                           0
# 1                                102        68                           0
# 2                                 44        23                           0
# 3                                 15        44                           1
# 4                                236        22                           1
# ...                              ...       ...                         ...
# 1995                              12        33                           1
# 1996                             160        56                           0
# 1997                             417        35                           1
# 1998                             458        56                           0
# 1999                             196        18                           0
#
#       Payment_Method_Debit Card  Payment_Method_Net Banking  \
# 0                             0                           1
# 1                             0                           0
# 2                             1                           0
# 3                             0                           0
# 4                             0                           0
# ...                         ...                         ...
# 1995                          0                           0
# 1996                          0                           1
# 1997                          0                           0
# 1998                          1                           0
# 1999                          0                           1
#
#       Payment_Method_UPI  Transaction_Status_Failed  \
# 0                      0                          1
# 1                      1                          1
# 2                      0                          0
# 3                      0                          0
# 4                      0                          0
# ...                  ...                        ...
# 1995                   0                          0
# 1996                   0                          0
# 1997                   0                          1
# 1998                   0                          1
# 1999                   0                          0
#
#       Transaction_Status_Pending  Transaction_Status_Success  \
# 0                              0                           0
# 1                              0                           0
# 2                              1                           0
# 3                              1                           0
# 4                              1                           0
# ...                          ...                         ...
# 1995                           1                           0
# 1996                           1                           0
# 1997                           0                           0
# 1998                           0                           0
# 1999                           0                           1
#
#       User_Account_Status_Active  User_Account_Status_Inactive  \
# 0                              0                             1
# 1                              0                             0
# 2                              1                             0
# 3                              0                             1
# 4                              0                             0
# ...                          ...                           ...
# 1995                           0                             0
# 1996                           0                             0
# 1997                           1                             0
# 1998                           0                             1
# 1999                           1                             0
#
#       User_Account_Status_Suspended  Merchant_Category_Electronics  \
# 0                                 0                              0
# 1                                 1                              0
# 2                                 0                              0
# 3                                 0                              0
# 4                                 1                              0
# ...                             ...                            ...
# 1995                              1                              0
# 1996                              1                              0
# 1997                              0                              0
# 1998                              0                              1
# 1999                              0                              0
#
#       Merchant_Category_Fashion  Merchant_Category_Grocery  \
# 0                             0                          1
# 1                             1                          0
# 2                             0                          0
# 3                             1                          0
# 4                             1                          0
# ...                         ...                        ...
# 1995                          0                          0
# 1996                          0                          0
# 1997                          0                          0
# 1998                          0                          0
# 1999                          0                          0
#
#       Merchant_Category_Healthcare  Merchant_Category_Travel
# 0                                0                         0
# 1                                0                         0
# 2                                0                         1
# 3                                0                         0
# 4                                0                         0
# ...                            ...                       ...
# 1995                             1                         0
# 1996                             0                         1
# 1997                             1                         0
# 1998                             0                         0
# 1999                             0                         1
#
# [2000 rows x 20 columns]

# %%
df.isnull().sum()
# Out:
# Transaction_Amount                0
# Fraud_Flag                        0
# User_Account_Balance              0
# User_Transaction_History_Count    0
# User_Age                          0
# Payment_Method_Credit Card        0
# Payment_Method_Debit Card         0
# Payment_Method_Net Banking        0
# Payment_Method_UPI                0
# Transaction_Status_Failed         0
# Transaction_Status_Pending        0
# Transaction_Status_Success        0
# User_Account_Status_Active        0
# User_Account_Status_Inactive      0
# User_Account_Status_Suspended     0
# Merchant_Category_Electronics     0
# Merchant_Category_Fashion         0
# Merchant_Category_Grocery         0
# Merchant_Category_Healthcare      0
# Merchant_Category_Travel          0
# dtype: int64

# %%
df['User_Transaction_History_Count'] = scaler.fit_transform(df['User_Transaction_History_Count'].values.reshape(-1, 1))

# %%
df['User_Age'] = scaler.fit_transform(df['User_Age'].values.reshape(-1, 1))

# %%
df
# Out:
#       Transaction_Amount  Fraud_Flag  User_Account_Balance  \
# 0               0.862547           0              0.837297
# 1               0.845043           0              0.078760
# 2               0.319279           0              0.091219
# 3               0.829401           1              0.427458
# 4               0.037018           1              0.134687
# ...                  ...         ...                   ...
# 1995            0.433015           0              0.704588
# 1996            0.685842           0              0.890703
# 1997            0.332644           0              0.916209
# 1998            0.056607           0              0.277683
# 1999            0.374134           0              0.187808
#
#       User_Transaction_History_Count  User_Age  Payment_Method_Credit Card  \
# 0                           0.819277  0.274510                           0
# 1                           0.202811  0.980392                           0
# 2                           0.086345  0.098039                           0
# 3                           0.028112  0.509804                           1
# 4                           0.471888  0.078431                           1
# ...                              ...       ...                         ...
# 1995                        0.022088  0.294118                           1
# 1996                        0.319277  0.745098                           0
# 1997                        0.835341  0.333333                           1
# 1998                        0.917671  0.745098                           0
# 1999                        0.391566  0.000000                           0
#
#       Payment_Method_Debit Card  Payment_Method_Net Banking  \
# 0                             0                           1
# 1                             0                           0
# 2                             1                           0
# 3                             0                           0
# 4                             0                           0
# ...                         ...                         ...
# 1995                          0                           0
# 1996                          0                           1
# 1997                          0                           0
# 1998                          1                           0
# 1999                          0                           1
#
#       Payment_Method_UPI  Transaction_Status_Failed  \
# 0                      0                          1
# 1                      1                          1
# 2                      0                          0
# 3                      0                          0
# 4                      0                          0
# ...                  ...                        ...
# 1995                   0                          0
# 1996                   0                          0
# 1997                   0                          1
# 1998                   0                          1
# 1999                   0                          0
#
#       Transaction_Status_Pending  Transaction_Status_Success  \
# 0                              0                           0
# 1                              0                           0
# 2                              1                           0
# 3                              1                           0
# 4                              1                           0
# ...                          ...                         ...
# 1995                           1                           0
# 1996                           1                           0
# 1997                           0                           0
# 1998                           0                           0
# 1999                           0                           1
#
#       User_Account_Status_Active  User_Account_Status_Inactive  \
# 0                              0                             1
# 1                              0                             0
# 2                              1                             0
# 3                              0                             1
# 4                              0                             0
# ...                          ...                           ...
# 1995                           0                             0
# 1996                           0                             0
# 1997                           1                             0
# 1998                           0                             1
# 1999                           1                             0
#
#       User_Account_Status_Suspended  Merchant_Category_Electronics  \
# 0                                 0                              0
# 1                                 1                              0
# 2                                 0                              0
# 3                                 0                              0
# 4                                 1                              0
# ...                             ...                            ...
# 1995                              1                              0
# 1996                              1                              0
# 1997                              0                              0
# 1998                              0                              1
# 1999                              0                              0
#
#       Merchant_Category_Fashion  Merchant_Category_Grocery  \
# 0                             0                          1
# 1                             1                          0
# 2                             0                          0
# 3                             1                          0
# 4                             1                          0
# ...                         ...                        ...
# 1995                          0                          0
# 1996                          0                          0
# 1997                          0                          0
# 1998                          0                          0
# 1999                          0                          0
#
#       Merchant_Category_Healthcare  Merchant_Category_Travel
# 0                                0                         0
# 1                                0                         0
# 2                                0                         1
# 3                                0                         0
# 4                                0                         0
# ...                            ...                       ...
# 1995                             1                         0
# 1996                             0                         1
# 1997                             1                         0
# 1998                             0                         0
# 1999                             0                         1
#
# [2000 rows x 20 columns]

# %%
df.to_csv('gpay_fraud_transaction_analysis_filtered.csv', index=False)

# %%
target_variable = 'Fraud_Flag'
continuous_features = ['Transaction_Amount', 'User_Account_Balance', 
                       'User_Transaction_History_Count', 'User_Age']
for feature in continuous_features:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=target_variable, y=feature, data=df)
    plt.title(f'Box Plot of {feature} by {target_variable}')
    plt.xlabel(target_variable)
    plt.ylabel(feature)
    plt.show()

# %%
sns.pairplot(df, vars=continuous_features, hue=target_variable, diag_kind='kde')
plt.suptitle('Pair Plot of Continuous Features', y=1.02)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
correlation_matrix = df.corr()

# Set up the matplotlib figure
plt.figure(figsize=(14, 10))

# Draw the heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)

# Set the title
plt.title("Correlation Matrix Heatmap", size=16)

# Show the plot
plt.show()

# Optional: Perform correlation analysis by extracting highly correlated pairs
threshold = 0.7
high_corr_pairs = correlation_matrix.unstack().abs().sort_values(ascending=False)
high_corr_pairs = high_corr_pairs[(high_corr_pairs > threshold) & (high_corr_pairs < 1)]

print("Highly correlated pairs (threshold > 0.7):")
print(high_corr_pairs)
# Out:
# Highly correlated pairs (threshold > 0.7):
# Series([], dtype: float64)

# %%
from sklearn.model_selection import GridSearchCV, KFold, train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
df
# Out:
#       Transaction_Amount  Fraud_Flag  User_Account_Balance  \
# 0               0.862547           0              0.837297
# 1               0.845043           0              0.078760
# 2               0.319279           0              0.091219
# 3               0.829401           1              0.427458
# 4               0.037018           1              0.134687
# ...                  ...         ...                   ...
# 1995            0.433015           0              0.704588
# 1996            0.685842           0              0.890703
# 1997            0.332644           0              0.916209
# 1998            0.056607           0              0.277683
# 1999            0.374134           0              0.187808
#
#       User_Transaction_History_Count  User_Age  Payment_Method_Credit Card  \
# 0                           0.819277  0.274510                           0
# 1                           0.202811  0.980392                           0
# 2                           0.086345  0.098039                           0
# 3                           0.028112  0.509804                           1
# 4                           0.471888  0.078431                           1
# ...                              ...       ...                         ...
# 1995                        0.022088  0.294118                           1
# 1996                        0.319277  0.745098                           0
# 1997                        0.835341  0.333333                           1
# 1998                        0.917671  0.745098                           0
# 1999                        0.391566  0.000000                           0
#
#       Payment_Method_Debit Card  Payment_Method_Net Banking  \
# 0                             0                           1
# 1                             0                           0
# 2                             1                           0
# 3                             0                           0
# 4                             0                           0
# ...                         ...                         ...
# 1995                          0                           0
# 1996                          0                           1
# 1997                          0                           0
# 1998                          1                           0
# 1999                          0                           1
#
#       Payment_Method_UPI  Transaction_Status_Failed  \
# 0                      0                          1
# 1                      1                          1
# 2                      0                          0
# 3                      0                          0
# 4                      0                          0
# ...                  ...                        ...
# 1995                   0                          0
# 1996                   0                          0
# 1997                   0                          1
# 1998                   0                          1
# 1999                   0                          0
#
#       Transaction_Status_Pending  Transaction_Status_Success  \
# 0                              0                           0
# 1                              0                           0
# 2                              1                           0
# 3                              1                           0
# 4                              1                           0
# ...                          ...                         ...
# 1995                           1                           0
# 1996                           1                           0
# 1997                           0                           0
# 1998                           0                           0
# 1999                           0                           1
#
#       User_Account_Status_Active  User_Account_Status_Inactive  \
# 0                              0                             1
# 1                              0                             0
# 2                              1                             0
# 3                              0                             1
# 4                              0                             0
# ...                          ...                           ...
# 1995                           0                             0
# 1996                           0                             0
# 1997                           1                             0
# 1998                           0                             1
# 1999                           1                             0
#
#       User_Account_Status_Suspended  Merchant_Category_Electronics  \
# 0                                 0                              0
# 1                                 1                              0
# 2                                 0                              0
# 3                                 0                              0
# 4                                 1                              0
# ...                             ...                            ...
# 1995                              1                              0
# 1996                              1                              0
# 1997                              0                              0
# 1998                              0                              1
# 1999                              0                              0
#
#       Merchant_Category_Fashion  Merchant_Category_Grocery  \
# 0                             0                          1
# 1                             1                          0
# 2                             0                          0
# 3                             1                          0
# 4                             1                          0
# ...                         ...                        ...
# 1995                          0                          0
# 1996                          0                          0
# 1997                          0                          0
# 1998                          0                          0
# 1999                          0                          0
#
#       Merchant_Category_Healthcare  Merchant_Category_Travel
# 0                                0                         0
# 1                                0                         0
# 2                                0                         1
# 3                                0                         0
# 4                                0                         0
# ...                            ...                       ...
# 1995                             1                         0
# 1996                             0                         1
# 1997                             1                         0
# 1998                             0                         0
# 1999                             0                         1
#
# [2000 rows x 20 columns]

# %%
X=df.drop("Fraud_Flag",axis=1)
y=df['Fraud_Flag']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
svm = SVC(kernel='linear')
svm.fit(X_train, y_train)
svm.score(X_test, y_test)
svm.score(X_train, y_train)
# Out:
# 0.9457142857142857

# %%
svm_poly = SVC(kernel='poly', degree=4, C = 2.5)
svm_poly.fit(X_train, y_train)
svm_poly.score(X_test, y_test)
# Out:
# 0.94

# %%
from sklearn.model_selection import cross_val_score
clf = SVC(kernel='linear', C=1, random_state=42)
scores = cross_val_score(clf, X, y, cv=5)
scores
# Out:
# array([0.9475, 0.9475, 0.9475, 0.9475, 0.9475])

# %%
svm = SVC(gamma='auto')
svm.fit(X_train, y_train)
svm.score(X_test, y_test)
# Out:
# 0.9516666666666667

# %%
svm_sig = SVC(kernel='sigmoid')
svm_sig.fit(X_train, y_train)
svm_sig.score(X_test, y_test)
# Out:
# 0.945

# %%
from sklearn.decomposition import PCA # Principal Component Analysis--for dimensionality reduction
from mlxtend.plotting import plot_decision_regions

# %%
pca = PCA(n_components=2)
x_train_pca = pca.fit_transform(X_train)
x_test_pca = pca.transform(X_test)

# %%
y_train = np.array(y_train)
y_test = np.array(y_test)
svm_pca = SVC()
svm_pca.fit(x_train_pca, y_train)
plot_decision_regions(x_train_pca, y_train, clf=svm_pca)
plt.figure()
plot_decision_regions(x_test_pca, y_test, clf=svm_pca)
svm_pca.score(x_test_pca, y_test)
# Out:
# 0.9516666666666667

# %%
svm_pca_linear = SVC(kernel='linear')
svm_pca_linear.fit(x_train_pca, y_train)
plot_decision_regions(x_train_pca, y_train, clf=svm_pca_linear)
plt.figure()
plot_decision_regions(x_test_pca, y_test, clf=svm_pca_linear)
plt.show()
svm_pca_linear.score(x_test_pca, y_test)
# Out:
# 0.9516666666666667

# %%
svm_pca_poly = SVC(kernel='poly', degree=7)
svm_pca_poly.fit(x_train_pca, y_train)
plot_decision_regions(x_train_pca, y_train, clf=svm_pca_poly)
plt.figure()
plot_decision_regions(x_test_pca, y_test, clf=svm_pca_poly)
plt.show()
svm_pca_poly.score(x_test_pca, y_test)
# Out:
# 0.9516666666666667

# %%
svm_pca_sig = SVC(kernel='sigmoid')
svm_pca_sig.fit(x_train_pca, y_train)
plot_decision_regions(x_train_pca, y_train, clf=svm_pca_sig)
plt.figure()
plot_decision_regions(x_test_pca, y_test, clf=svm_pca_sig)
plt.show()
svm_pca_sig.score(x_test_pca, y_test)
# Out:
# 0.9516666666666667

# %%
from sklearn.model_selection import cross_val_score
import numpy as np

# %%
score_svm =cross_val_score(SVC(gamma='auto'),df, df['Fraud_Flag'],cv=3)

print(score_svm)

print("Avg :",np.average(score_svm))
# Out:
# [1. 1. 1.]
# Avg : 1.0

# %%
param_grid = {
    'C': [0.1, 1, 10, 100],
    'gamma': ['scale', 'auto', 0.001, 0.01, 0.1, 1],
    'kernel': ['linear', 'rbf', 'poly']
}

# %%
svc = SVC()

# %%
grid_search = GridSearchCV(estimator=svc, param_grid=param_grid, cv=5, verbose=2, n_jobs=-1)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100],
#                          'gamma': ['scale', 'auto', 0.001, 0.01, 0.1, 1],
#                          'kernel': ['linear', 'rbf', 'poly']},
#              verbose=2)

# %%
print("Best parameters found: ", grid_search.best_params_)
print("Best cross-validation score: ", grid_search.best_score_)
# Out:
# Best parameters found:  {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# Best cross-validation score:  0.9457142857142857

# %%
y_pred = grid_search.best_estimator_.predict(X_test)

# %%
print("\nClassification report:\n", classification_report(y_test, y_pred))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98       571
#            1       0.00      0.00      0.00        29
#
#     accuracy                           0.95       600
#    macro avg       0.48      0.50      0.49       600
# weighted avg       0.91      0.95      0.93       600
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy: 95.17%

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Non-Fraud', 'Fraud'], yticklabels=['Non-Fraud', 'Fraud'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
